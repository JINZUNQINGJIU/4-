# %%
#coding:utf-8
#导入warnings包，利用过滤器来实现忽略警告语句。
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
traindata=pd.read_csv('F:\二手车\car_train_0110.csv',sep=' ')
testdata=pd.read_csv('F:\二手车\car_testA_0110.csv',sep=' ')

# %%
traindata.head()
# Out:
#    SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  power  \
# 0  134890     734  20160002   13.0      9       NaN       0.0      1.0      0
# 1  306648  196973  20080307   72.0      9       7.0       5.0      1.0    173
# 2  340675   25347  20020312   18.0     12       3.0       0.0      1.0     50
# 3   57332    5382  20000611   38.0      8       7.0       0.0      1.0     54
# 4  265235  173174  20030109   87.0      0       5.0       5.0      1.0    131
#
#    kilometer  ...      v_14      v_15       v_16      v_17      v_18  \
# 0       15.0  ...  0.092139  0.000000  18.763832 -1.512063 -1.008718
# 1       15.0  ...  0.001070  0.122335  -5.685612 -0.489963 -2.223693
# 2       12.5  ...  0.064410  0.003345  -3.295700  1.816499  3.554439
# 3       15.0  ...  0.069231  0.000000  -3.405521  1.497826  4.782636
# 4        3.0  ...  0.000099  0.001655  -4.475429  0.124138  1.364567
#
#         v_19      v_20      v_21      v_22      v_23
# ...

# %%
testdata.head()
# Out:
#    SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  power  \
# 0  720326     505  20060505   19.0     13       7.0       0.0      1.0     90
# 1  714316    1836  20010301    5.0      5       3.0       4.0      1.0     75
# 2  704693  212291  20170610    6.0     18       NaN       5.0      0.0    150
# 3  624972    1345  19820005  215.0     32       7.0       0.0      1.0      0
# 4  669753    1428  20060205   30.0      4       7.0       5.0      1.0    122
#
#    kilometer  ...      v_14      v_15      v_16      v_17      v_18  \
# 0        8.0  ...  0.083340  0.105382 -5.998993  0.147048 -1.902847
# 1       15.0  ...  0.074478  0.000000 -3.287221  2.081317  2.937052
# 2       15.0  ...  0.002032  0.000000  4.368218  8.252188 -4.136109
# 3        6.0  ...  0.098806  0.100883 -2.537486  0.513955  4.414962
# 4       15.0  ...  0.088397  0.002509 -6.197633 -0.191814 -1.224360
#
#         v_19      v_20      v_21      v_22      v_23
# ...

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 40 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SaleID             250000 non-null  int64
#  1   name               250000 non-null  int64
#  2   regDate            250000 non-null  int64
#  3   model              250000 non-null  float64
#  4   brand              250000 non-null  int64
#  5   bodyType           224620 non-null  float64
#  6   fuelType           227510 non-null  float64
#  7   gearbox            236487 non-null  float64
#  8   power              250000 non-null  int64
#  9   kilometer          250000 non-null  float64
#  10  notRepairedDamage  201464 non-null  float64
#  11  regionCode         250000 non-null  int64
#  12  seller             250000 non-null  int64
#  13  offerType          250000 non-null  int64
#  14  creatDate          250000 non-null  int64
# ...

# %%
traindata.isnull().sum()
# Out:
# SaleID                   0
# name                     0
# regDate                  0
# model                    0
# brand                    0
# bodyType             25380
# fuelType             22490
# gearbox              13513
# power                    0
# kilometer                0
# notRepairedDamage    48536
# regionCode               0
# seller                   0
# offerType                0
# creatDate                0
# price                    0
# v_0                      0
# v_1                      0
# v_2                      0
# v_3                      0
# v_4                      0
# v_5                      0
# v_6                      0
# v_7                      0
# v_8                      0
# v_9                      0
# v_10                     0
# v_11                     0
# v_12                     0
# v_13                     0
# v_14                     0
# v_15                     0
# v_16                     0
# v_17                     0
# ...

# %% [markdown]
# 可以看出，bodytype，fuelType，gearbox，notRepairedDamage均有缺失值

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SaleID             50000 non-null  int64
#  1   name               50000 non-null  int64
#  2   regDate            50000 non-null  int64
#  3   model              50000 non-null  float64
#  4   brand              50000 non-null  int64
#  5   bodyType           44890 non-null  float64
#  6   fuelType           45598 non-null  float64
#  7   gearbox            47287 non-null  float64
#  8   power              50000 non-null  int64
#  9   kilometer          50000 non-null  float64
#  10  notRepairedDamage  40372 non-null  float64
#  11  regionCode         50000 non-null  int64
#  12  seller             50000 non-null  int64
#  13  offerType          50000 non-null  int64
#  14  creatDate          50000 non-null  int64
#  15  v_0                50000 non-null  float64
# ...

# %%
traindata.describe()
# Out:
#               SaleID           name       regDate          model  \
# count  250000.000000  250000.000000  2.500000e+05  250000.000000
# mean   185351.790768   83153.362172  2.003401e+07      44.911480
# std    107121.188763   72540.799964  7.770250e+04      50.640081
# min         1.000000       0.000000  1.910000e+07       0.000000
# 25%     92501.750000   14500.000000  1.999061e+07       6.000000
# 50%    185264.500000   65314.500000  2.003111e+07      27.000000
# 75%    278128.500000  143761.250000  2.008081e+07      70.000000
# max    370946.000000  233044.000000  2.019121e+07     250.000000
#
#                brand       bodyType       fuelType        gearbox  \
# count  250000.000000  224620.000000  227510.000000  236487.000000
# mean        7.785236       4.563271       1.665008       0.780783
# std         7.694010       1.912515       2.339646       0.413717
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
testdata.describe()
# Out:
#               SaleID           name       regDate         model         brand  \
# count   50000.000000   50000.000000  5.000000e+04  50000.000000  50000.000000
# mean   556029.053380   82878.251420  2.003441e+07     44.922840      7.779420
# std    106952.402565   72292.076936  7.788055e+04     50.576255      7.661667
# min    370951.000000       0.000000  1.910000e+07      0.000000      0.000000
# 25%    463258.500000   14121.250000  1.999061e+07      6.000000      1.000000
# 50%    556296.000000   65359.000000  2.003111e+07     27.000000      6.000000
# 75%    648862.250000  143083.750000  2.008091e+07     70.000000     11.000000
# max    741887.000000  233028.000000  2.019040e+07    248.000000     39.000000
#
#            bodyType      fuelType       gearbox         power     kilometer  \
# count  44890.000000  45598.000000  47287.000000  50000.000000  50000.000000
# mean       4.556226      1.681192      0.781081    114.116060     12.555210
# ...

# %% [markdown]
# 由于比赛前期已经对数据进行过建模，使用的方案为Bi-lstm.我采用的方案是将缺失值全部设为-1，然后利用task3特征工程进行离散化和归一化。因为有缺失值的部分都是类别特征，但是缺失值的数量又比较多，不能将其剔除，但是又不能设为0，如果设置为0的话会对结果产生较大影响，后面利用互信息的方式对每个特征和价格的相关性进行了计算。结果如下：

# %% [raw]
# feature_cols,carnmi
# model,0.1183162754174238
# brand,0.05298787880104686
# bodyType,0.04084944378774965
# fuelType,0.03195356234358269
# gearbox,0.024801228349346296
# power,0.13651930226247122
# kilometer,0.05134858909106972
# notRepairedDamage,0.03130729404267111
# regionCode,0.3421126305995645
# seller,6.4184342099265305e-06
# offerType,4.182662394872487e-05
# v_0,0.6583808550695546
# v_1,0.6583808550695543
# v_2,0.6583808550695545
# v_3,0.6583808550695546
# v_4,0.6583808550695543
# v_5,0.6583808550695546
# v_6,0.6583808550695543
# v_7,0.6583808550695543
# v_8,0.6142033141672417
# v_9,0.6583808550695542
# v_10,0.6357966080577717
# v_11,0.6676476451657527
# v_12,0.6387119688142765
# v_13,0.6464095320637543
# v_14,0.6272832970319189
# v_15,0.5688107197350819
# v_16,0.6583808550695546
# v_17,0.6583808550695543
# v_18,0.6583808550695545
# v_19,0.6583808550695545
# v_20,0.6583808550695545
# v_21,0.6583808550695543
# v_22,0.6583808550695543
# v_23,0.6583808550695542
# used_time,0.3902458979590597

# %% [markdown]
# 后期特征工程可以考虑删去重要性小于0.05的特征进行建模，以提高模型的精度。

# %% [markdown]
# the end
